# %% [markdown]
# <a href="https://colab.research.google.com/github/jwellik/csav_seismology/blob/main/00_Play_w_vdapseisutils.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install git+https://github.com/jwellik/vdapseisutils.git
# Out:
# ...
#   Cloning https://github.com/jwellik/vdapseisutils.git to /tmp/pip-req-build-d2yomcrn
#   Running command git clone --filter=blob:none --quiet https://github.com/jwellik/vdapseisutils.git /tmp/pip-req-build-d2yomcrn
#   Resolved https://github.com/jwellik/vdapseisutils.git to commit 549e44ddb61404f6d7942165a55bfb665aef1870
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# INFO: pip is looking at multiple versions of vdapseisutils to determine which version is compatible with other requirements. This could take a while.
# ERROR: Package 'vdapseisutils' requires a different Python: 3.11.12 not in '>=3.12'
